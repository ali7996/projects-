# %% [markdown]
# # Text Classification with Traditional Models
# The Twitter dataset (`tweets.csv`) was collected in February of 2015. Contributors were asked to first classify positive, negative, and neutral tweets, followed by categorizing negative reasons (such as "late flight" or "rude service"). The dataset can be found [here.](https://www.kaggle.com/crowdflower/twitter-airline-sentiment)
#
# You should build an end-to-end NLP pipeline to predict the sentiment class (i.e., positive, negative, or neutral) given a tweet. In particular, you should do the following:
# - Load the `tweets` dataset using [Pandas](https://pandas.pydata.org/docs/reference/api/pandas.read_csv.html). You can find this dataset in the datasets folder.
# - Split the dataset into training and test sets using [Scikit-Learn](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html).
# - Build an end-to-end NLP pipeline, including a text representation model, such as [TF-IDF vectorizer](https://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.TfidfVectorizer.html), and a traditional classification model, such as [naive bayes](https://scikit-learn.org/stable/modules/generated/sklearn.naive_bayes.MultinomialNB.html).
# - Optimize your pipeline by cross-validating your design decisions.
# - Test the best pipeline on the test set and report various [evaluation metrics](https://scikit-learn.org/0.15/modules/model_evaluation.html).
# - Check the documentation to identify the most important hyperparameters, attributes, and methods of the model. Use them in practice.

# %%
import pandas as pd 
import nltk
import optuna
import numpy as np
import sklearn.model_selection
from nltk.tokenize import RegexpTokenizer
from nltk.stem import PorterStemmer
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_recall_fscore_support
from sklearn.model_selection import cross_val_score

# %%
df=pd.read_csv("/content/tweets.csv")
df.head()
# Out:
#              tweet_id airline_sentiment  airline_sentiment_confidence  \
# 0  570306133677760513           neutral                        1.0000
# 1  570301130888122368          positive                        0.3486
# 2  570301083672813571           neutral                        0.6837
# 3  570301031407624196          negative                        1.0000
# 4  570300817074462722          negative                        1.0000
#
#   negativereason  negativereason_confidence         airline  \
# 0            NaN                        NaN  Virgin America
# 1            NaN                     0.0000  Virgin America
# 2            NaN                        NaN  Virgin America
# 3     Bad Flight                     0.7033  Virgin America
# 4     Can't Tell                     1.0000  Virgin America
#
#   airline_sentiment_gold        name negativereason_gold  retweet_count  \
# 0                    NaN     cairdin                 NaN              0
# 1                    NaN    jnardino                 NaN              0
# 2                    NaN  yvonnalynn                 NaN              0
# 3                    NaN    jnardino                 NaN              0
# 4                    NaN    jnardino                 NaN              0
#
#                                                 text tweet_coord  \
# 0                @VirginAmerica What @dhepburn said.         NaN
# 1  @VirginAmerica plus you've added commercials t...         NaN
# 2  @VirginAmerica I didn't today... Must mean I n...         NaN
# 3  @VirginAmerica it's really aggressive to blast...         NaN
# 4  @VirginAmerica and it's a really big bad thing...         NaN
#
#                tweet_created tweet_location               user_timezone
# 0  2015-02-24 11:35:52 -0800            NaN  Eastern Time (US & Canada)
# 1  2015-02-24 11:15:59 -0800            NaN  Pacific Time (US & Canada)
# 2  2015-02-24 11:15:48 -0800      Lets Play  Central Time (US & Canada)
# 3  2015-02-24 11:15:36 -0800            NaN  Pacific Time (US & Canada)
# 4  2015-02-24 11:14:45 -0800            NaN  Pacific Time (US & Canada)

# %% [markdown]
# # **Data pre-processing**

# %% [markdown]
# **1-lower case the letters**

# %%
text=df["text"][10]
print('the original tweet')
print(text)
print('the lower case tweet')
print(text.lower())
# Out:
# the original tweet
# @VirginAmerica did you know that suicide is the second leading cause of death among teens 10-24
# the lower case tweet
# @virginamerica did you know that suicide is the second leading cause of death among teens 10-24

# %% [markdown]
# **2-remove symboles**

# %%
tokenizer=RegexpTokenizer(r'\w+|\$[\d\.]+|\S+@')
words=tokenizer.tokenize(text)
print(words)
# Out:
# ['VirginAmerica', 'did', 'you', 'know', 'that', 'suicide', 'is', 'the', 'second', 'leading', 'cause', 'of', 'death', 'among', 'teens', '10', '24']

# %% [markdown]
# **3-steaming**

# %%
porter_stemmer=PorterStemmer()
stemmed_words=[porter_stemmer.stem(w) for w in words]
print(stemmed_words)
# Out:
# ['virginamerica', 'did', 'you', 'know', 'that', 'suicid', 'is', 'the', 'second', 'lead', 'caus', 'of', 'death', 'among', 'teen', '10', '24']

# %% [markdown]
# **4- join the pre-processed words together**

# %%
preprocessed=" ".join(stemmed_words)
print(preprocessed)
# Out:
# virginamerica did you know that suicid is the second lead caus of death among teen 10 24

# %% [markdown]
# # **Apply all the pre-processing on all the data**

# %%
def preprocessor(text):
  #make lower case
  text=text.lower()
  #remove sympoles
  tokenizer=RegexpTokenizer(r'\w+|\$[\d\.]+|\S+@')
  words=tokenizer.tokenize(text)
  #stemming 
  porter_stemmer=PorterStemmer()
  stemmed_words=[porter_stemmer.stem(w) for w in words]

  return " ".join(stemmed_words)
df['reprocessed_data']=df['text'].apply(preprocessor)
df.head()
# Out:
#              tweet_id airline_sentiment  airline_sentiment_confidence  \
# 0  570306133677760513           neutral                        1.0000
# 1  570301130888122368          positive                        0.3486
# 2  570301083672813571           neutral                        0.6837
# 3  570301031407624196          negative                        1.0000
# 4  570300817074462722          negative                        1.0000
#
#   negativereason  negativereason_confidence         airline  \
# 0            NaN                        NaN  Virgin America
# 1            NaN                     0.0000  Virgin America
# 2            NaN                        NaN  Virgin America
# 3     Bad Flight                     0.7033  Virgin America
# 4     Can't Tell                     1.0000  Virgin America
#
#   airline_sentiment_gold        name negativereason_gold  retweet_count  \
# 0                    NaN     cairdin                 NaN              0
# 1                    NaN    jnardino                 NaN              0
# 2                    NaN  yvonnalynn                 NaN              0
# 3                    NaN    jnardino                 NaN              0
# 4                    NaN    jnardino                 NaN              0
#
#                                                 text tweet_coord  \
# 0                @VirginAmerica What @dhepburn said.         NaN
# 1  @VirginAmerica plus you've added commercials t...         NaN
# 2  @VirginAmerica I didn't today... Must mean I n...         NaN
# 3  @VirginAmerica it's really aggressive to blast...         NaN
# 4  @VirginAmerica and it's a really big bad thing...         NaN
#
#                tweet_created tweet_location               user_timezone  \
# 0  2015-02-24 11:35:52 -0800            NaN  Eastern Time (US & Canada)
# 1  2015-02-24 11:15:59 -0800            NaN  Pacific Time (US & Canada)
# 2  2015-02-24 11:15:48 -0800      Lets Play  Central Time (US & Canada)
# 3  2015-02-24 11:15:36 -0800            NaN  Pacific Time (US & Canada)
# 4  2015-02-24 11:14:45 -0800            NaN  Pacific Time (US & Canada)
#
#                                     reprocessed_data
# 0                   virginamerica what dhepburn said
# 1  virginamerica plu you ve ad commerci to the ex...
# 2  virginamerica i didn t today must mean i need ...
# 3  virginamerica it s realli aggress to blast obn...
# 4  virginamerica and it s a realli big bad thing ...

# %% [markdown]
# # **Split the data into Train and Test**

# %%
x= df["reprocessed_data"]
y = df["airline_sentiment"]
x_train, x_test, y_train, y_test = sklearn. model_selection.train_test_split(x, y)

# %% [markdown]
# # **Vectorization**

# %%
vectorizer = sklearn. feature_extraction.text. TfidfVectorizer (min_df=5)
vectorizer.fit (x_train)
x_train = vectorizer.transform(x_train).toarray ()
x_test = vectorizer.transform(x_test).toarray ()
print("new x train:" ,x_train.shape)
print( "new × test:",x_test.shape)
# Out:
# new x train: (10980, 2174)
# new × test: (3660, 2174)

# %% [markdown]
# # **MODEL TRAINING AND TUNNING HYPER PARAMETERS**

# %%
def objective(trial):
    # Define the search space for the hyperparameter
    var_smoothing = trial.suggest_loguniform('var_smoothing', 1e-10, 1e-6)
    
    # Create an instance of the Naive Bayes classifier with the suggested hyperparameter
    gnb = GaussianNB(var_smoothing=var_smoothing)
    
    # Perform cross-validation with accuracy as the scoring metric
    scores = cross_val_score(gnb, x_train, y_train, cv=5, scoring='accuracy')
    
    # Calculate the mean accuracy score
    mean_accuracy = scores.mean()
    
    return mean_accuracy

study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=100)

print('The best accuracy achieved: {:.2f}'.format(study.best_value * 100))
print('The best hyperparameters: {}'.format(study.best_params))
# Out:
# [I 2023-05-19 21:47:36,640] A new study created in memory with name: no-name-2827cb0a-d6f9-40a7-ae13-5afc4d92c859
# <ipython-input-21-ffaf1fa6c689>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   var_smoothing = trial.suggest_loguniform('var_smoothing', 1e-10, 1e-6)
# [I 2023-05-19 21:47:39,426] Trial 0 finished with value: 0.4156648451730419 and parameters: {'var_smoothing': 1.911191312948378e-09}. Best is trial 0 with value: 0.4156648451730419.
# <ipython-input-21-ffaf1fa6c689>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   var_smoothing = trial.suggest_loguniform('var_smoothing', 1e-10, 1e-6)
# [I 2023-05-19 21:47:42,177] Trial 1 finished with value: 0.4292349726775956 and parameters: {'var_smoothing': 8.515776486426551e-07}. Best is trial 1 with value: 0.4292349726775956.
# <ipython-input-21-ffaf1fa6c689>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   var_smoothing = trial.suggest_loguniform('var_smoothing', 1e-10, 1e-6)
# [I 2023-05-19 21:47:46,448] Trial 2 finished with value: 0.41502732240437157 and parameters: {'var_smoothing': 7.859657281229854e-10}. Best is trial 1 with value: 0.4292349726775956.
# <ipython-input-21-ffaf1fa6c689>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   var_smoothing = trial.suggest_loguniform('var_smoothing', 1e-10, 1e-6)
# [I 2023-05-19 21:47:49,342] Trial 3 finished with value: 0.4148451730418944 and parameters: {'var_smoothing': 6.068472184819438e-10}. Best is trial 1 with value: 0.4292349726775956.
# <ipython-input-21-ffaf1fa6c689>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   var_smoothing = trial.suggest_loguniform('var_smoothing', 1e-10, 1e-6)
# [I 2023-05-19 21:47:52,093] Trial 4 finished with value: 0.4182149362477231 and parameters: {'var_smoothing': 1.822505105953475e-08}. Best is trial 1 with value: 0.4292349726775956.
# <ipython-input-21-ffaf1fa6c689>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   var_smoothing = trial.suggest_loguniform('var_smoothing', 1e-10, 1e-6)
# [I 2023-05-19 21:47:54,844] Trial 5 finished with value: 0.4204007285974499 and parameters: {'var_smoothing': 6.538622084127888e-08}. Best is trial 1 with value: 0.4292349726775956.
# <ipython-input-21-ffaf1fa6c689>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   var_smoothing = trial.suggest_loguniform('var_smoothing', 1e-10, 1e-6)
# [I 2023-05-19 21:47:57,680] Trial 6 finished with value: 0.4184881602914389 and parameters: {'var_smoothing': 2.5277169272981308e-08}. Best is trial 1 with value: 0.4292349726775956.
# <ipython-input-21-ffaf1fa6c689>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   var_smoothing = trial.suggest_loguniform('var_smoothing', 1e-10, 1e-6)
# [I 2023-05-19 21:48:00,778] Trial 7 finished with value: 0.4148451730418944 and parameters: {'var_smoothing': 2.3349563367595775e-10}. Best is trial 1 with value: 0.4292349726775956.
# <ipython-input-21-ffaf1fa6c689>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   var_smoothing = trial.suggest_loguniform('var_smoothing', 1e-10, 1e-6)
# [I 2023-05-19 21:48:03,504] Trial 8 finished with value: 0.42477231329690357 and parameters: {'var_smoothing': 2.658132179057481e-07}. Best is trial 1 with value: 0.4292349726775956.
# <ipython-input-21-ffaf1fa6c689>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   var_smoothing = trial.suggest_loguniform('var_smoothing', 1e-10, 1e-6)
# [I 2023-05-19 21:48:06,225] Trial 9 finished with value: 0.43041894353369764 and parameters: {'var_smoothing': 9.956116231087637e-07}. Best is trial 9 with value: 0.43041894353369764.
# <ipython-input-21-ffaf1fa6c689>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   var_smoothing = trial.suggest_loguniform('var_smoothing', 1e-10, 1e-6)
# [I 2023-05-19 21:48:08,967] Trial 10 finished with value: 0.4284153005464481 and parameters: {'var_smoothing': 7.587976164326429e-07}. Best is trial 9 with value: 0.43041894353369764.
# <ipython-input-21-ffaf1fa6c689>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   var_smoothing = trial.suggest_loguniform('var_smoothing', 1e-10, 1e-6)
# [I 2023-05-19 21:48:12,613] Trial 11 finished with value: 0.43023679417122035 and parameters: {'var_smoothing': 9.249054317786378e-07}. Best is trial 9 with value: 0.43041894353369764.
# <ipython-input-21-ffaf1fa6c689>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   var_smoothing = trial.suggest_loguniform('var_smoothing', 1e-10, 1e-6)
# [I 2023-05-19 21:48:15,551] Trial 12 finished with value: 0.4224043715846994 and parameters: {'var_smoothing': 1.5975035610806076e-07}. Best is trial 9 with value: 0.43041894353369764.
# <ipython-input-21-ffaf1fa6c689>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   var_smoothing = trial.suggest_loguniform('var_smoothing', 1e-10, 1e-6)
# [I 2023-05-19 21:48:18,313] Trial 13 finished with value: 0.4241347905282331 and parameters: {'var_smoothing': 2.2272030788773428e-07}. Best is trial 9 with value: 0.43041894353369764.
# <ipython-input-21-ffaf1fa6c689>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   var_smoothing = trial.suggest_loguniform('var_smoothing', 1e-10, 1e-6)
# [I 2023-05-19 21:48:21,080] Trial 14 finished with value: 0.4285974499089253 and parameters: {'var_smoothing': 7.953247356960369e-07}. Best is trial 9 with value: 0.43041894353369764.
# <ipython-input-21-ffaf1fa6c689>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   var_smoothing = trial.suggest_loguniform('var_smoothing', 1e-10, 1e-6)
# [I 2023-05-19 21:48:23,836] Trial 15 finished with value: 0.4172131147540984 and parameters: {'var_smoothing': 6.635399230082608e-09}. Best is trial 9 with value: 0.43041894353369764.
# <ipython-input-21-ffaf1fa6c689>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   var_smoothing = trial.suggest_loguniform('var_smoothing', 1e-10, 1e-6)
# [I 2023-05-19 21:48:27,779] Trial 16 finished with value: 0.4199453551912569 and parameters: {'var_smoothing': 5.871065082195157e-08}. Best is trial 9 with value: 0.43041894353369764.
# <ipython-input-21-ffaf1fa6c689>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   var_smoothing = trial.suggest_loguniform('var_smoothing', 1e-10, 1e-6)
# [I 2023-05-19 21:48:30,491] Trial 17 finished with value: 0.4257741347905283 and parameters: {'var_smoothing': 3.5135143896314873e-07}. Best is trial 9 with value: 0.43041894353369764.
# <ipython-input-21-ffaf1fa6c689>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   var_smoothing = trial.suggest_loguniform('var_smoothing', 1e-10, 1e-6)
# [I 2023-05-19 21:48:33,216] Trial 18 finished with value: 0.4218579234972678 and parameters: {'var_smoothing': 1.1299097809251411e-07}. Best is trial 9 with value: 0.43041894353369764.
# <ipython-input-21-ffaf1fa6c689>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   var_smoothing = trial.suggest_loguniform('var_smoothing', 1e-10, 1e-6)
# [I 2023-05-19 21:48:35,943] Trial 19 finished with value: 0.42604735883424405 and parameters: {'var_smoothing': 4.244321974886632e-07}. Best is trial 9 with value: 0.43041894353369764.
# <ipython-input-21-ffaf1fa6c689>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   var_smoothing = trial.suggest_loguniform('var_smoothing', 1e-10, 1e-6)
# [I 2023-05-19 21:48:38,865] Trial 20 finished with value: 0.42595628415300546 and parameters: {'var_smoothing': 4.1596121268225495e-07}. Best is trial 9 with value: 0.43041894353369764.
# <ipython-input-21-ffaf1fa6c689>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   var_smoothing = trial.suggest_loguniform('var_smoothing', 1e-10, 1e-6)
# [I 2023-05-19 21:48:41,827] Trial 21 finished with value: 0.4284153005464481 and parameters: {'var_smoothing': 7.255593007550442e-07}. Best is trial 9 with value: 0.43041894353369764.
# <ipython-input-21-ffaf1fa6c689>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   var_smoothing = trial.suggest_loguniform('var_smoothing', 1e-10, 1e-6)
# [I 2023-05-19 21:48:44,555] Trial 22 finished with value: 0.4275956284153005 and parameters: {'var_smoothing': 5.879779484651009e-07}. Best is trial 9 with value: 0.43041894353369764.
# <ipython-input-21-ffaf1fa6c689>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   var_smoothing = trial.suggest_loguniform('var_smoothing', 1e-10, 1e-6)
# [I 2023-05-19 21:48:47,714] Trial 23 finished with value: 0.4218579234972678 and parameters: {'var_smoothing': 1.132787072680814e-07}. Best is trial 9 with value: 0.43041894353369764.
# <ipython-input-21-ffaf1fa6c689>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   var_smoothing = trial.suggest_loguniform('var_smoothing', 1e-10, 1e-6)
# [I 2023-05-19 21:48:50,478] Trial 24 finished with value: 0.4287795992714026 and parameters: {'var_smoothing': 8.169836915273424e-07}. Best is trial 9 with value: 0.43041894353369764.
# <ipython-input-21-ffaf1fa6c689>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   var_smoothing = trial.suggest_loguniform('var_smoothing', 1e-10, 1e-6)
# [I 2023-05-19 21:48:53,520] Trial 25 finished with value: 0.43041894353369764 and parameters: {'var_smoothing': 9.700581224892244e-07}. Best is trial 9 with value: 0.43041894353369764.
# <ipython-input-21-ffaf1fa6c689>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   var_smoothing = trial.suggest_loguniform('var_smoothing', 1e-10, 1e-6)
# [I 2023-05-19 21:48:56,343] Trial 26 finished with value: 0.425591985428051 and parameters: {'var_smoothing': 3.1217036680069837e-07}. Best is trial 9 with value: 0.43041894353369764.
# <ipython-input-21-ffaf1fa6c689>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   var_smoothing = trial.suggest_loguniform('var_smoothing', 1e-10, 1e-6)
# [I 2023-05-19 21:48:59,070] Trial 27 finished with value: 0.4224043715846994 and parameters: {'var_smoothing': 1.5037365781587902e-07}. Best is trial 9 with value: 0.43041894353369764.
# <ipython-input-21-ffaf1fa6c689>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   var_smoothing = trial.suggest_loguniform('var_smoothing', 1e-10, 1e-6)
# [I 2023-05-19 21:49:01,832] Trial 28 finished with value: 0.4257741347905283 and parameters: {'var_smoothing': 3.661014694198082e-07}. Best is trial 9 with value: 0.43041894353369764.
# <ipython-input-21-ffaf1fa6c689>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   var_smoothing = trial.suggest_loguniform('var_smoothing', 1e-10, 1e-6)
# [I 2023-05-19 21:49:04,682] Trial 29 finished with value: 0.43041894353369764 and parameters: {'var_smoothing': 9.813166639610104e-07}. Best is trial 9 with value: 0.43041894353369764.
# <ipython-input-21-ffaf1fa6c689>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   var_smoothing = trial.suggest_loguniform('var_smoothing', 1e-10, 1e-6)
# [I 2023-05-19 21:49:07,710] Trial 30 finished with value: 0.42422586520947175 and parameters: {'var_smoothing': 2.2655800827889985e-07}. Best is trial 9 with value: 0.43041894353369764.
# <ipython-input-21-ffaf1fa6c689>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   var_smoothing = trial.suggest_loguniform('var_smoothing', 1e-10, 1e-6)
# [I 2023-05-19 21:49:10,453] Trial 31 finished with value: 0.43041894353369764 and parameters: {'var_smoothing': 9.993191966360663e-07}. Best is trial 9 with value: 0.43041894353369764.
# <ipython-input-21-ffaf1fa6c689>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   var_smoothing = trial.suggest_loguniform('var_smoothing', 1e-10, 1e-6)
# [I 2023-05-19 21:49:13,233] Trial 32 finished with value: 0.43041894353369764 and parameters: {'var_smoothing': 9.625752546394539e-07}. Best is trial 9 with value: 0.43041894353369764.
# <ipython-input-21-ffaf1fa6c689>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   var_smoothing = trial.suggest_loguniform('var_smoothing', 1e-10, 1e-6)
# [I 2023-05-19 21:49:16,013] Trial 33 finished with value: 0.42650273224043717 and parameters: {'var_smoothing': 4.926505355917354e-07}. Best is trial 9 with value: 0.43041894353369764.
# <ipython-input-21-ffaf1fa6c689>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   var_smoothing = trial.suggest_loguniform('var_smoothing', 1e-10, 1e-6)
# [I 2023-05-19 21:49:18,978] Trial 34 finished with value: 0.4265938069216758 and parameters: {'var_smoothing': 4.988867129926272e-07}. Best is trial 9 with value: 0.43041894353369764.
# <ipython-input-21-ffaf1fa6c689>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   var_smoothing = trial.suggest_loguniform('var_smoothing', 1e-10, 1e-6)
# [I 2023-05-19 21:49:21,928] Trial 35 finished with value: 0.4301457194899818 and parameters: {'var_smoothing': 9.166614755624756e-07}. Best is trial 9 with value: 0.43041894353369764.
# <ipython-input-21-ffaf1fa6c689>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   var_smoothing = trial.suggest_loguniform('var_smoothing', 1e-10, 1e-6)
# [I 2023-05-19 21:49:24,660] Trial 36 finished with value: 0.4263205828779599 and parameters: {'var_smoothing': 4.388016737640108e-07}. Best is trial 9 with value: 0.43041894353369764.
# <ipython-input-21-ffaf1fa6c689>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   var_smoothing = trial.suggest_loguniform('var_smoothing', 1e-10, 1e-6)
# [I 2023-05-19 21:49:27,397] Trial 37 finished with value: 0.424408014571949 and parameters: {'var_smoothing': 2.332711259619712e-07}. Best is trial 9 with value: 0.43041894353369764.
# <ipython-input-21-ffaf1fa6c689>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   var_smoothing = trial.suggest_loguniform('var_smoothing', 1e-10, 1e-6)
# [I 2023-05-19 21:49:30,131] Trial 38 finished with value: 0.4210382513661203 and parameters: {'var_smoothing': 8.422888116305912e-08}. Best is trial 9 with value: 0.43041894353369764.
# <ipython-input-21-ffaf1fa6c689>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   var_smoothing = trial.suggest_loguniform('var_smoothing', 1e-10, 1e-6)
# [I 2023-05-19 21:49:33,081] Trial 39 finished with value: 0.41948998178506375 and parameters: {'var_smoothing': 5.1470664165066476e-08}. Best is trial 9 with value: 0.43041894353369764.
# <ipython-input-21-ffaf1fa6c689>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   var_smoothing = trial.suggest_loguniform('var_smoothing', 1e-10, 1e-6)
# [I 2023-05-19 21:49:35,972] Trial 40 finished with value: 0.42704918032786876 and parameters: {'var_smoothing': 5.28170956503641e-07}. Best is trial 9 with value: 0.43041894353369764.
# <ipython-input-21-ffaf1fa6c689>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   var_smoothing = trial.suggest_loguniform('var_smoothing', 1e-10, 1e-6)
# [I 2023-05-19 21:49:38,737] Trial 41 finished with value: 0.43023679417122035 and parameters: {'var_smoothing': 9.466046548116926e-07}. Best is trial 9 with value: 0.43041894353369764.
# <ipython-input-21-ffaf1fa6c689>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   var_smoothing = trial.suggest_loguniform('var_smoothing', 1e-10, 1e-6)
# [I 2023-05-19 21:49:41,500] Trial 42 finished with value: 0.4273224043715847 and parameters: {'var_smoothing': 5.741337910403511e-07}. Best is trial 9 with value: 0.43041894353369764.
# <ipython-input-21-ffaf1fa6c689>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   var_smoothing = trial.suggest_loguniform('var_smoothing', 1e-10, 1e-6)
# [I 2023-05-19 21:49:44,324] Trial 43 finished with value: 0.430327868852459 and parameters: {'var_smoothing': 9.587335202562784e-07}. Best is trial 9 with value: 0.43041894353369764.
# <ipython-input-21-ffaf1fa6c689>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   var_smoothing = trial.suggest_loguniform('var_smoothing', 1e-10, 1e-6)
# [I 2023-05-19 21:49:47,356] Trial 44 finished with value: 0.42531876138433516 and parameters: {'var_smoothing': 2.9707355192015705e-07}. Best is trial 9 with value: 0.43041894353369764.
# <ipython-input-21-ffaf1fa6c689>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   var_smoothing = trial.suggest_loguniform('var_smoothing', 1e-10, 1e-6)
# [I 2023-05-19 21:49:50,077] Trial 45 finished with value: 0.43041894353369764 and parameters: {'var_smoothing': 9.903889094848605e-07}. Best is trial 9 with value: 0.43041894353369764.
# <ipython-input-21-ffaf1fa6c689>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   var_smoothing = trial.suggest_loguniform('var_smoothing', 1e-10, 1e-6)
# [I 2023-05-19 21:49:52,843] Trial 46 finished with value: 0.42367941712204005 and parameters: {'var_smoothing': 2.0455683146137288e-07}. Best is trial 9 with value: 0.43041894353369764.
# <ipython-input-21-ffaf1fa6c689>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   var_smoothing = trial.suggest_loguniform('var_smoothing', 1e-10, 1e-6)
# [I 2023-05-19 21:49:55,577] Trial 47 finished with value: 0.4276867030965391 and parameters: {'var_smoothing': 6.076730614022926e-07}. Best is trial 9 with value: 0.43041894353369764.
# <ipython-input-21-ffaf1fa6c689>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   var_smoothing = trial.suggest_loguniform('var_smoothing', 1e-10, 1e-6)
# [I 2023-05-19 21:49:58,606] Trial 48 finished with value: 0.42568306010928963 and parameters: {'var_smoothing': 3.4012252885311995e-07}. Best is trial 9 with value: 0.43041894353369764.
# <ipython-input-21-ffaf1fa6c689>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   var_smoothing = trial.suggest_loguniform('var_smoothing', 1e-10, 1e-6)
# [I 2023-05-19 21:50:01,922] Trial 49 finished with value: 0.4280510018214937 and parameters: {'var_smoothing': 6.55584200251832e-07}. Best is trial 9 with value: 0.43041894353369764.
# <ipython-input-21-ffaf1fa6c689>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   var_smoothing = trial.suggest_loguniform('var_smoothing', 1e-10, 1e-6)
# [I 2023-05-19 21:50:04,922] Trial 50 finished with value: 0.42304189435336975 and parameters: {'var_smoothing': 1.777011256725963e-07}. Best is trial 9 with value: 0.43041894353369764.
# <ipython-input-21-ffaf1fa6c689>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   var_smoothing = trial.suggest_loguniform('var_smoothing', 1e-10, 1e-6)
# [I 2023-05-19 21:50:07,643] Trial 51 finished with value: 0.43041894353369764 and parameters: {'var_smoothing': 9.918140770836338e-07}. Best is trial 9 with value: 0.43041894353369764.
# <ipython-input-21-ffaf1fa6c689>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   var_smoothing = trial.suggest_loguniform('var_smoothing', 1e-10, 1e-6)
# [I 2023-05-19 21:50:10,376] Trial 52 finished with value: 0.42777777777777776 and parameters: {'var_smoothing': 6.213647628890661e-07}. Best is trial 9 with value: 0.43041894353369764.
# <ipython-input-21-ffaf1fa6c689>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   var_smoothing = trial.suggest_loguniform('var_smoothing', 1e-10, 1e-6)
# [I 2023-05-19 21:50:13,104] Trial 53 finished with value: 0.42504553734061934 and parameters: {'var_smoothing': 2.8591939184562356e-07}. Best is trial 9 with value: 0.43041894353369764.
# <ipython-input-21-ffaf1fa6c689>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   var_smoothing = trial.suggest_loguniform('var_smoothing', 1e-10, 1e-6)
# [I 2023-05-19 21:50:16,152] Trial 54 finished with value: 0.4284153005464481 and parameters: {'var_smoothing': 6.928676454000325e-07}. Best is trial 9 with value: 0.43041894353369764.
# <ipython-input-21-ffaf1fa6c689>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   var_smoothing = trial.suggest_loguniform('var_smoothing', 1e-10, 1e-6)
# [I 2023-05-19 21:50:18,949] Trial 55 finished with value: 0.43041894353369764 and parameters: {'var_smoothing': 9.867042000313442e-07}. Best is trial 9 with value: 0.43041894353369764.
# <ipython-input-21-ffaf1fa6c689>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   var_smoothing = trial.suggest_loguniform('var_smoothing', 1e-10, 1e-6)
# [I 2023-05-19 21:50:21,682] Trial 56 finished with value: 0.4261384335154827 and parameters: {'var_smoothing': 4.262271514683737e-07}. Best is trial 9 with value: 0.43041894353369764.
# <ipython-input-21-ffaf1fa6c689>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   var_smoothing = trial.suggest_loguniform('var_smoothing', 1e-10, 1e-6)
# [I 2023-05-19 21:50:24,427] Trial 57 finished with value: 0.4280510018214937 and parameters: {'var_smoothing': 6.711231612991585e-07}. Best is trial 9 with value: 0.43041894353369764.
# <ipython-input-21-ffaf1fa6c689>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   var_smoothing = trial.suggest_loguniform('var_smoothing', 1e-10, 1e-6)
# [I 2023-05-19 21:50:27,234] Trial 58 finished with value: 0.4257741347905283 and parameters: {'var_smoothing': 3.89327517682295e-07}. Best is trial 9 with value: 0.43041894353369764.
# <ipython-input-21-ffaf1fa6c689>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   var_smoothing = trial.suggest_loguniform('var_smoothing', 1e-10, 1e-6)
# [I 2023-05-19 21:50:30,310] Trial 59 finished with value: 0.42504553734061934 and parameters: {'var_smoothing': 2.8645845107712243e-07}. Best is trial 9 with value: 0.43041894353369764.
# <ipython-input-21-ffaf1fa6c689>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   var_smoothing = trial.suggest_loguniform('var_smoothing', 1e-10, 1e-6)
# [I 2023-05-19 21:50:33,079] Trial 60 finished with value: 0.4284153005464481 and parameters: {'var_smoothing': 7.074142745154768e-07}. Best is trial 9 with value: 0.43041894353369764.
# <ipython-input-21-ffaf1fa6c689>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   var_smoothing = trial.suggest_loguniform('var_smoothing', 1e-10, 1e-6)
# [I 2023-05-19 21:50:35,845] Trial 61 finished with value: 0.43023679417122035 and parameters: {'var_smoothing': 9.522146849550156e-07}. Best is trial 9 with value: 0.43041894353369764.
# <ipython-input-21-ffaf1fa6c689>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   var_smoothing = trial.suggest_loguniform('var_smoothing', 1e-10, 1e-6)
# [I 2023-05-19 21:50:38,582] Trial 62 finished with value: 0.43041894353369764 and parameters: {'var_smoothing': 9.725539170426846e-07}. Best is trial 9 with value: 0.43041894353369764.
# <ipython-input-21-ffaf1fa6c689>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   var_smoothing = trial.suggest_loguniform('var_smoothing', 1e-10, 1e-6)
# [I 2023-05-19 21:50:41,531] Trial 63 finished with value: 0.42650273224043717 and parameters: {'var_smoothing': 4.826488025989583e-07}. Best is trial 9 with value: 0.43041894353369764.
# <ipython-input-21-ffaf1fa6c689>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   var_smoothing = trial.suggest_loguniform('var_smoothing', 1e-10, 1e-6)
# [I 2023-05-19 21:50:44,481] Trial 64 finished with value: 0.4280510018214937 and parameters: {'var_smoothing': 6.730674289061628e-07}. Best is trial 9 with value: 0.43041894353369764.
# <ipython-input-21-ffaf1fa6c689>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   var_smoothing = trial.suggest_loguniform('var_smoothing', 1e-10, 1e-6)
# [I 2023-05-19 21:50:47,261] Trial 65 finished with value: 0.42650273224043717 and parameters: {'var_smoothing': 4.834448281444086e-07}. Best is trial 9 with value: 0.43041894353369764.
# <ipython-input-21-ffaf1fa6c689>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   var_smoothing = trial.suggest_loguniform('var_smoothing', 1e-10, 1e-6)
# [I 2023-05-19 21:50:50,020] Trial 66 finished with value: 0.42568306010928963 and parameters: {'var_smoothing': 3.3980012788792865e-07}. Best is trial 9 with value: 0.43041894353369764.
# <ipython-input-21-ffaf1fa6c689>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   var_smoothing = trial.suggest_loguniform('var_smoothing', 1e-10, 1e-6)
# [I 2023-05-19 21:50:52,767] Trial 67 finished with value: 0.43041894353369764 and parameters: {'var_smoothing': 9.673659124977615e-07}. Best is trial 9 with value: 0.43041894353369764.
# <ipython-input-21-ffaf1fa6c689>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   var_smoothing = trial.suggest_loguniform('var_smoothing', 1e-10, 1e-6)
# [I 2023-05-19 21:50:55,816] Trial 68 finished with value: 0.4284153005464481 and parameters: {'var_smoothing': 7.149236861190906e-07}. Best is trial 9 with value: 0.43041894353369764.
# <ipython-input-21-ffaf1fa6c689>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   var_smoothing = trial.suggest_loguniform('var_smoothing', 1e-10, 1e-6)
# [I 2023-05-19 21:50:58,634] Trial 69 finished with value: 0.424408014571949 and parameters: {'var_smoothing': 2.466723684321679e-07}. Best is trial 9 with value: 0.43041894353369764.
# <ipython-input-21-ffaf1fa6c689>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   var_smoothing = trial.suggest_loguniform('var_smoothing', 1e-10, 1e-6)
# [I 2023-05-19 21:51:01,407] Trial 70 finished with value: 0.4258652094717668 and parameters: {'var_smoothing': 4.0256883101348946e-07}. Best is trial 9 with value: 0.43041894353369764.
# <ipython-input-21-ffaf1fa6c689>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   var_smoothing = trial.suggest_loguniform('var_smoothing', 1e-10, 1e-6)
# [I 2023-05-19 21:51:04,160] Trial 71 finished with value: 0.4287795992714026 and parameters: {'var_smoothing': 8.176802170629838e-07}. Best is trial 9 with value: 0.43041894353369764.
# <ipython-input-21-ffaf1fa6c689>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   var_smoothing = trial.suggest_loguniform('var_smoothing', 1e-10, 1e-6)
# [I 2023-05-19 21:51:06,989] Trial 72 finished with value: 0.43041894353369764 and parameters: {'var_smoothing': 9.845925159974962e-07}. Best is trial 9 with value: 0.43041894353369764.
# <ipython-input-21-ffaf1fa6c689>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   var_smoothing = trial.suggest_loguniform('var_smoothing', 1e-10, 1e-6)
# [I 2023-05-19 21:51:10,014] Trial 73 finished with value: 0.4269581056466302 and parameters: {'var_smoothing': 5.247184011377845e-07}. Best is trial 9 with value: 0.43041894353369764.
# <ipython-input-21-ffaf1fa6c689>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   var_smoothing = trial.suggest_loguniform('var_smoothing', 1e-10, 1e-6)
# [I 2023-05-19 21:51:12,783] Trial 74 finished with value: 0.42832422586520946 and parameters: {'var_smoothing': 7.553529790954569e-07}. Best is trial 9 with value: 0.43041894353369764.
# <ipython-input-21-ffaf1fa6c689>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   var_smoothing = trial.suggest_loguniform('var_smoothing', 1e-10, 1e-6)
# [I 2023-05-19 21:51:15,540] Trial 75 finished with value: 0.4269581056466302 and parameters: {'var_smoothing': 5.176502758195613e-07}. Best is trial 9 with value: 0.43041894353369764.
# <ipython-input-21-ffaf1fa6c689>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   var_smoothing = trial.suggest_loguniform('var_smoothing', 1e-10, 1e-6)
# [I 2023-05-19 21:51:18,263] Trial 76 finished with value: 0.4284153005464481 and parameters: {'var_smoothing': 7.373539948861569e-07}. Best is trial 9 with value: 0.43041894353369764.
# <ipython-input-21-ffaf1fa6c689>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   var_smoothing = trial.suggest_loguniform('var_smoothing', 1e-10, 1e-6)
# [I 2023-05-19 21:51:21,189] Trial 77 finished with value: 0.4257741347905283 and parameters: {'var_smoothing': 3.7698145257384354e-07}. Best is trial 9 with value: 0.43041894353369764.
# <ipython-input-21-ffaf1fa6c689>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   var_smoothing = trial.suggest_loguniform('var_smoothing', 1e-10, 1e-6)
# [I 2023-05-19 21:51:24,160] Trial 78 finished with value: 0.42741347905282334 and parameters: {'var_smoothing': 5.799110743425692e-07}. Best is trial 9 with value: 0.43041894353369764.
# <ipython-input-21-ffaf1fa6c689>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   var_smoothing = trial.suggest_loguniform('var_smoothing', 1e-10, 1e-6)
# [I 2023-05-19 21:51:26,907] Trial 79 finished with value: 0.43041894353369764 and parameters: {'var_smoothing': 9.916815975313105e-07}. Best is trial 9 with value: 0.43041894353369764.
# <ipython-input-21-ffaf1fa6c689>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   var_smoothing = trial.suggest_loguniform('var_smoothing', 1e-10, 1e-6)
# [I 2023-05-19 21:51:29,729] Trial 80 finished with value: 0.4285974499089253 and parameters: {'var_smoothing': 7.899268298593535e-07}. Best is trial 9 with value: 0.43041894353369764.
# <ipython-input-21-ffaf1fa6c689>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   var_smoothing = trial.suggest_loguniform('var_smoothing', 1e-10, 1e-6)
# [I 2023-05-19 21:51:32,548] Trial 81 finished with value: 0.43041894353369764 and parameters: {'var_smoothing': 9.69875229124814e-07}. Best is trial 9 with value: 0.43041894353369764.
# <ipython-input-21-ffaf1fa6c689>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   var_smoothing = trial.suggest_loguniform('var_smoothing', 1e-10, 1e-6)
# [I 2023-05-19 21:51:36,269] Trial 82 finished with value: 0.4273224043715847 and parameters: {'var_smoothing': 5.733412799104774e-07}. Best is trial 9 with value: 0.43041894353369764.
# <ipython-input-21-ffaf1fa6c689>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   var_smoothing = trial.suggest_loguniform('var_smoothing', 1e-10, 1e-6)
# [I 2023-05-19 21:51:39,033] Trial 83 finished with value: 0.4287795992714026 and parameters: {'var_smoothing': 8.097335961815787e-07}. Best is trial 9 with value: 0.43041894353369764.
# <ipython-input-21-ffaf1fa6c689>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   var_smoothing = trial.suggest_loguniform('var_smoothing', 1e-10, 1e-6)
# [I 2023-05-19 21:51:41,791] Trial 84 finished with value: 0.42622950819672134 and parameters: {'var_smoothing': 4.486978572588189e-07}. Best is trial 9 with value: 0.43041894353369764.
# <ipython-input-21-ffaf1fa6c689>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   var_smoothing = trial.suggest_loguniform('var_smoothing', 1e-10, 1e-6)
# [I 2023-05-19 21:51:44,523] Trial 85 finished with value: 0.42723132969034605 and parameters: {'var_smoothing': 5.700938306397281e-07}. Best is trial 9 with value: 0.43041894353369764.
# <ipython-input-21-ffaf1fa6c689>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   var_smoothing = trial.suggest_loguniform('var_smoothing', 1e-10, 1e-6)
# [I 2023-05-19 21:51:47,419] Trial 86 finished with value: 0.42896174863387976 and parameters: {'var_smoothing': 8.191536625980638e-07}. Best is trial 9 with value: 0.43041894353369764.
# <ipython-input-21-ffaf1fa6c689>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   var_smoothing = trial.suggest_loguniform('var_smoothing', 1e-10, 1e-6)
# [I 2023-05-19 21:51:50,457] Trial 87 finished with value: 0.425591985428051 and parameters: {'var_smoothing': 3.250528468483985e-07}. Best is trial 9 with value: 0.43041894353369764.
# <ipython-input-21-ffaf1fa6c689>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   var_smoothing = trial.suggest_loguniform('var_smoothing', 1e-10, 1e-6)
# [I 2023-05-19 21:51:53,248] Trial 88 finished with value: 0.4280510018214937 and parameters: {'var_smoothing': 6.398901459519588e-07}. Best is trial 9 with value: 0.43041894353369764.
# <ipython-input-21-ffaf1fa6c689>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   var_smoothing = trial.suggest_loguniform('var_smoothing', 1e-10, 1e-6)
# [I 2023-05-19 21:51:55,999] Trial 89 finished with value: 0.42622950819672134 and parameters: {'var_smoothing': 4.496887108248731e-07}. Best is trial 9 with value: 0.43041894353369764.
# <ipython-input-21-ffaf1fa6c689>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   var_smoothing = trial.suggest_loguniform('var_smoothing', 1e-10, 1e-6)
# [I 2023-05-19 21:51:58,755] Trial 90 finished with value: 0.43041894353369764 and parameters: {'var_smoothing': 9.96686558580994e-07}. Best is trial 9 with value: 0.43041894353369764.
# <ipython-input-21-ffaf1fa6c689>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   var_smoothing = trial.suggest_loguniform('var_smoothing', 1e-10, 1e-6)
# [I 2023-05-19 21:52:01,750] Trial 91 finished with value: 0.42868852459016393 and parameters: {'var_smoothing': 8.019378412730395e-07}. Best is trial 9 with value: 0.43041894353369764.
# <ipython-input-21-ffaf1fa6c689>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   var_smoothing = trial.suggest_loguniform('var_smoothing', 1e-10, 1e-6)
# [I 2023-05-19 21:52:04,658] Trial 92 finished with value: 0.43041894353369764 and parameters: {'var_smoothing': 9.949047059625162e-07}. Best is trial 9 with value: 0.43041894353369764.
# <ipython-input-21-ffaf1fa6c689>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   var_smoothing = trial.suggest_loguniform('var_smoothing', 1e-10, 1e-6)
# [I 2023-05-19 21:52:07,407] Trial 93 finished with value: 0.42777777777777776 and parameters: {'var_smoothing': 6.321488737314602e-07}. Best is trial 9 with value: 0.43041894353369764.
# <ipython-input-21-ffaf1fa6c689>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   var_smoothing = trial.suggest_loguniform('var_smoothing', 1e-10, 1e-6)
# [I 2023-05-19 21:52:10,135] Trial 94 finished with value: 0.4285974499089253 and parameters: {'var_smoothing': 7.934094790511679e-07}. Best is trial 9 with value: 0.43041894353369764.
# <ipython-input-21-ffaf1fa6c689>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   var_smoothing = trial.suggest_loguniform('var_smoothing', 1e-10, 1e-6)
# [I 2023-05-19 21:52:12,889] Trial 95 finished with value: 0.4273224043715847 and parameters: {'var_smoothing': 5.601791604727474e-07}. Best is trial 9 with value: 0.43041894353369764.
# <ipython-input-21-ffaf1fa6c689>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   var_smoothing = trial.suggest_loguniform('var_smoothing', 1e-10, 1e-6)
# [I 2023-05-19 21:52:16,005] Trial 96 finished with value: 0.4257741347905283 and parameters: {'var_smoothing': 3.701220413701928e-07}. Best is trial 9 with value: 0.43041894353369764.
# <ipython-input-21-ffaf1fa6c689>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   var_smoothing = trial.suggest_loguniform('var_smoothing', 1e-10, 1e-6)
# [I 2023-05-19 21:52:18,761] Trial 97 finished with value: 0.4285974499089253 and parameters: {'var_smoothing': 7.957159347697317e-07}. Best is trial 9 with value: 0.43041894353369764.
# <ipython-input-21-ffaf1fa6c689>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   var_smoothing = trial.suggest_loguniform('var_smoothing', 1e-10, 1e-6)
# [I 2023-05-19 21:52:21,506] Trial 98 finished with value: 0.42477231329690357 and parameters: {'var_smoothing': 2.7794899900987237e-07}. Best is trial 9 with value: 0.43041894353369764.
# <ipython-input-21-ffaf1fa6c689>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   var_smoothing = trial.suggest_loguniform('var_smoothing', 1e-10, 1e-6)
# [I 2023-05-19 21:52:24,237] Trial 99 finished with value: 0.4263205828779599 and parameters: {'var_smoothing': 4.7513000220343016e-07}. Best is trial 9 with value: 0.43041894353369764.
# The best accuracy achieved: 43.04
# The best hyperparameters: {'var_smoothing': 9.956116231087637e-07}

# %% [markdown]
# # **MODEL ASSESSMENT**

# %%
best_params = study.best_params

gnb = GaussianNB(var_smoothing=best_params['var_smoothing'])
gnb.fit(x_train, y_train)

y_predicted = gnb.predict(x_test)

accuracy = accuracy_score(y_test, y_predicted)
precision, recall, f1, support = precision_recall_fscore_support(y_test, y_predicted)
cm = confusion_matrix(y_test, y_predicted)

print('Accuracy: {:.2f}%'.format(accuracy * 100))
print('Precision:', precision)
print('Recall:', recall)
print('F1-score:', f1)
print('Confusion matrix:')
print(cm)
# Out:
# Accuracy: 40.03%
# Precision: [0.86368843 0.27114967 0.24718499]
# Recall: [0.33407178 0.31605563 0.75326797]
# F1-score: [0.48178914 0.29188558 0.37222447]
# Confusion matrix:
# [[754 569 934]
#  [ 71 250 470]
#  [ 48 103 461]]
